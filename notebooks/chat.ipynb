# %% [markdown]
# ## Problem Statement
#
# Given a chat script that is a group of chat transcript between customer and agent, classify customer question to different classifcation groups. These groups later needs to be tied to an intent for createing chatbots

# %% [markdown]
# ### Phase 1: Data Cleanup and pre processing
# __Step 1:__ Before loading the file add a line *Raw chat* as the first line in the txt file. This is done to ensure that first line is picked up as column name when we use Pandas, other wise it will create a column name as *"Activity Id: 1286172"*.

# %%
import pandas as pd

chat_df = pd.read_fwf(filepath_or_buffer="eGain Transcript sample.txt", delimiter="\n" )
#Fix column Name 
chat_df =chat_df.rename(index=str,columns={'Raw chat':'raw_chat'})

# %%
chat_df.head()
# Out:
#                                             raw_chat
# 0                                Activity ID: 143595
# 1  2017-06-16 18:36:06 Stuart Parker: Refinancing...
# 2  2017-06-16 18:36:14 system: You are now chatti...
# 3  2017-06-16 18:36:17 David L.: ^0aWelcome to We...
# 4  2017-06-16 18:36:28 David L.: The first step w...

# %% [markdown]
# __Step 2__: Extract Time stamp and chat into two seprate columns

# %%
#The time stamp format ex - "2017-06-16 18:36:06" has length of 20 chars. 
# To extract we need to avoid lines that start with Activity ID: xxx as they too are of length 20.
def getTimeStamp(row):
    first_20col= row['raw_chat']
    if(first_20col.count("Activity") == 0 ):
        return first_20col[0:19]

# %%
#Cut time stamp and create a new column
chat_df['timestamp'] = chat_df.apply(getTimeStamp, axis=1)

# %%
chat_df.head(30)
# Out:
#                                              raw_chat            timestamp
# 0                                 Activity ID: 143595                 None
# 1   2017-06-16 18:36:06 Stuart Parker: Refinancing...  2017-06-16 18:36:06
# 2   2017-06-16 18:36:14 system: You are now chatti...  2017-06-16 18:36:14
# 3   2017-06-16 18:36:17 David L.: ^0aWelcome to We...  2017-06-16 18:36:17
# 4   2017-06-16 18:36:28 David L.: The first step w...  2017-06-16 18:36:28
# 5                 2017-06-16 18:36:44 Stuart Parker:   2017-06-16 18:36:44
# 6   2017-06-16 18:36:44 Stuart Parker: I purchased...  2017-06-16 18:36:44
# 7   2017-06-16 18:37:02 Stuart Parker: and I had i...  2017-06-16 18:37:02
# 8   2017-06-16 18:37:29 Stuart Parker: but I was u...  2017-06-16 18:37:29
# 9                 2017-06-16 18:37:29 Stuart Parker:   2017-06-16 18:37:29
# 10  2017-06-16 18:37:53 Stuart Parker: So I have b...  2017-06-16 18:37:53
# 11  2017-06-16 18:38:05 David L.: Correct. You can...  2017-06-16 18:38:05
# 12                2017-06-16 18:38:06 Stuart Parker:   2017-06-16 18:38:06
# 13  2017-06-16 18:38:06 Stuart Parker: to have her...  2017-06-16 18:38:06
# 14  2017-06-16 18:38:29 Stuart Parker: So I am beg...  2017-06-16 18:38:29
# 15                2017-06-16 18:38:47 Stuart Parker:   2017-06-16 18:38:47
# 16  2017-06-16 18:38:47 Stuart Parker: and wanted ...  2017-06-16 18:38:47
# 17  2017-06-16 18:40:28 Stuart Parker: I am assumi...  2017-06-16 18:40:28
# 18  2017-06-16 18:41:10 David L.: You are not mist...  2017-06-16 18:41:10
# 19  2017-06-16 18:41:36 Stuart Parker: Thanks I wi...  2017-06-16 18:41:36
# 20  2017-06-16 18:41:44 David L.: You're welcome! ...  2017-06-16 18:41:44
# 21    2017-06-16 18:42:01 Stuart Parker: Thanks Again  2017-06-16 18:42:01
# 22                2017-06-16 18:42:01 Stuart Parker:   2017-06-16 18:42:01
# 23  2017-06-16 18:42:11 David L.: David L. has end...  2017-06-16 18:42:11
# 24                                Activity ID: 143954                 None
# 25  2017-06-16 20:12:30 system: Chat has been init...  2017-06-16 20:12:30
# 26  2017-06-16 20:12:33 system: You are now chatti...  2017-06-16 20:12:33
# 27  2017-06-16 20:12:37 David L.: ^0aWelcome to We...  2017-06-16 20:12:37
# 28  2017-06-16 20:14:36 Amber Webb: Hello I have a...  2017-06-16 20:14:36
# 29  2017-06-16 20:15:49 David L.: I will pass your...  2017-06-16 20:15:49

# %% [markdown]
# >To Extract just the chat without time stamp, we need take text that does not start with timestamp or Activity Id

# %%
#If the row does not start with Activity ID:xxxx then slice the Timesatmp and return text after 20 chars 
def getChatText(row):
    raw_chat= row['raw_chat']
    if(raw_chat.count("Activity") == 0 ):
        return raw_chat[20:]
    else:
        return raw_chat

# %%
chat_df['chat'] = chat_df.apply(getChatText, axis=1)

# %%
chat_df.head()
# Out:
#                                             raw_chat            timestamp  \
# 0                                Activity ID: 143595                 None
# 1  2017-06-16 18:36:06 Stuart Parker: Refinancing...  2017-06-16 18:36:06
# 2  2017-06-16 18:36:14 system: You are now chatti...  2017-06-16 18:36:14
# 3  2017-06-16 18:36:17 David L.: ^0aWelcome to We...  2017-06-16 18:36:17
# 4  2017-06-16 18:36:28 David L.: The first step w...  2017-06-16 18:36:28
#
#                                                 chat
# 0                                Activity ID: 143595
# 1      Stuart Parker: Refinancing a recent auto loan
# 2         system: You are now chatting with David L.
# 3  David L.: ^0aWelcome to Wells Fargo. How can I...
# 4  David L.: The first step would be to fill out ...

# %% [markdown]
# __Step 3:__ Drop the column **raw_chat** and create a column **activity_id** and populate with the chat activity Id. Now every column in **chat** does not have keyword Activity ID. So on on first occurence of __Activity ID__, extract the id and save it in global variable **activity_id**. For every line after that keep populating the id from global varibale. When the next **Activity ID: xxxx** is found, it means that new chat session has started, so update the value of global variable **activity_id**.

# %%
#Global Variable
activity_id=0

def getActivityId(row):
    global activity_id
    chat = row['chat']
    if(chat.count("Activity") == 0):
        return activity_id
    else:
        activity_id=chat[13:] # Will get the value after text "Activity ID: "

# %%
#Drop the first column
chat_df = chat_df.drop(columns="raw_chat")

#Create a column activity_id and fill in column 
chat_df['activity'] = chat_df.apply(getActivityId,axis=1)

# %%
chat_df.head(30)
# Out:
#               timestamp                                               chat  \
# 0                  None                                Activity ID: 143595
# 1   2017-06-16 18:36:06      Stuart Parker: Refinancing a recent auto loan
# 2   2017-06-16 18:36:14         system: You are now chatting with David L.
# 3   2017-06-16 18:36:17  David L.: ^0aWelcome to Wells Fargo. How can I...
# 4   2017-06-16 18:36:28  David L.: The first step would be to fill out ...
# 5   2017-06-16 18:36:44                                    Stuart Parker:
# 6   2017-06-16 18:36:44  Stuart Parker: I purchased a car recently (***...
# 7   2017-06-16 18:37:02  Stuart Parker: and I had intended to have my d...
# 8   2017-06-16 18:37:29  Stuart Parker: but I was unaware that I needed...
# 9   2017-06-16 18:37:29                                    Stuart Parker:
# 10  2017-06-16 18:37:53  Stuart Parker: So I have been informed that I ...
# 11  2017-06-16 18:38:05  David L.: Correct. You can apply for a refinan...
# 12  2017-06-16 18:38:06                                    Stuart Parker:
# 13  2017-06-16 18:38:06            Stuart Parker: to have her on the title
# 14  2017-06-16 18:38:29  Stuart Parker: So I am beginning the process o...
# 15  2017-06-16 18:38:47                                    Stuart Parker:
# 16  2017-06-16 18:38:47  Stuart Parker: and wanted to make sure I was n...
# 17  2017-06-16 18:40:28  Stuart Parker: I am assuming that I should req...
# 18  2017-06-16 18:41:10  David L.: You are not mistaken.  It does look ...
# 19  2017-06-16 18:41:36                Stuart Parker: Thanks I will switch
# 20  2017-06-16 18:41:44  David L.: You're welcome! Thank you for your i...
# 21  2017-06-16 18:42:01                        Stuart Parker: Thanks Again
# 22  2017-06-16 18:42:01                                    Stuart Parker:
# 23  2017-06-16 18:42:11              David L.: David L. has ended the chat
# 24                 None                                Activity ID: 143954
# 25  2017-06-16 20:12:30       system: Chat has been initiated by customer.
# 26  2017-06-16 20:12:33         system: You are now chatting with David L.
# 27  2017-06-16 20:12:37  David L.: ^0aWelcome to Wells Fargo. How can I...
# 28  2017-06-16 20:14:36  Amber Webb: Hello I have a Possible pending Lo...
# 29  2017-06-16 20:15:49    David L.: I will pass your message on to Jacob.
#
#    activity
# 0      None
# 1    143595
# 2    143595
# 3    143595
# 4    143595
# 5    143595
# 6    143595
# 7    143595
# 8    143595
# 9    143595
# 10   143595
# 11   143595
# 12   143595
# 13   143595
# 14   143595
# 15   143595
# 16   143595
# 17   143595
# 18   143595
# 19   143595
# 20   143595
# 21   143595
# 22   143595
# 23   143595
# 24     None
# 25   143954
# 26   143954
# 27   143954
# 28   143954
# 29   143954

# %% [markdown]
# **Step 4:** Drop all the rows where **chat** starts with **Activity Id: xxx** OR column timestamp is **None** or column **activity_id** is **None**. These rows are not required since we have already captured the activity ID information in its own column.

# %%
#Remove Rows with Activity Id
chat_df= chat_df.replace(to_replace='None', value=np.nan).dropna()

# %%
chat_df.head()
# Out:
#              timestamp                                               chat  \
# 1  2017-06-16 18:36:06      Stuart Parker: Refinancing a recent auto loan
# 2  2017-06-16 18:36:14         system: You are now chatting with David L.
# 3  2017-06-16 18:36:17  David L.: ^0aWelcome to Wells Fargo. How can I...
# 4  2017-06-16 18:36:28  David L.: The first step would be to fill out ...
# 5  2017-06-16 18:36:44                                    Stuart Parker:
#
#   activity
# 1   143595
# 2   143595
# 3   143595
# 4   143595
# 5   143595

# %% [markdown]
# __Step 5:__ Drop all the unnecessary lines such as
# - "Welcome to Wells fargo. How can I help you today?"
# - "system: Chat has been initiated by customer."
# - "David L.: David L. has ended the chat"

# %%
chat_df=chat_df[~chat_df['chat'].str.contains('Welcome to Wells Fargo.')]
chat_df=chat_df[~chat_df['chat'].str.contains('Welcome to Wells Fargo.')]
chat_df=chat_df[~chat_df['chat'].str.contains('has ended the chat')]
chat_df=chat_df[~chat_df['chat'].str.contains('Chat has been initiated by customer')]
chat_df=chat_df[~chat_df['chat'].str.contains('You are now chatting with')]

# %%
chat_df.describe()
# Out:
#                   timestamp  \
# count                 29868
# unique                28427
# top     2017-07-25 17:12:58
# freq                      4
#
#                                                      chat activity
# count                                               29868    29868
# unique                                              22438     4555
# top     David L.: Thank you for your interest in Wells...  1103696
# freq                                                 1278       52
